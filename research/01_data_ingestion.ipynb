# %%
import os

# %%
# %pwd
# Out:
# '/Users/amanuelmoges/Desktop/untitled folder 2/Text_Summerizer/Text_Summerizer'

# %%
os.chdir("/Users/amanuelmoges/Desktop/untitled folder 2/Text_Summerizer/Text_Summerizer/src")

# %%
# %pwd
# Out:
# '/Users/amanuelmoges/Desktop/untitled folder 2/Text_Summerizer/Text_Summerizer/src'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True )
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from textsummerizer.constants import *
from textsummerizer.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 2
#       1 from textsummerizer.constants import *
# ----> 2 from textsummerizer.utils.common import read_yaml, create_directories
#
# ImportError: cannot import name 'create_directories' from 'textsummerizer.utils.common' (/Users/amanuelmoges/Desktop/untitled folder 2/Text_Summerizer/Text_Summerizer/src/textsummerizer/utils/common.py)

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=Path(config.root_dir),
            source_URL=config.source_URL,
            local_data_file=Path(config.local_data_file),
            unzip_dir=Path(config.unzip_dir),
        )

        return data_ingestion_config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class ConfigurationManager:
#       2     def __init__(
#       3         self,
#       4         config_filepath=CONFIG_FILE_PATH,
#       5         params_filepath=PARAMS_FILE_PATH,
#       6     ):
#       7         self.config = read_yaml(config_filepath)
#
# Cell In[9], line 4, in ConfigurationManager()
#       1 class ConfigurationManager:
#       2     def __init__(
#       3         self,
# ----> 4         config_filepath=CONFIG_FILE_PATH,
#       5         params_filepath=PARAMS_FILE_PATH,
#       6     ):
#       7         self.config = read_yaml(config_filepath)
#       8         self.params = read_yaml(params_filepath)
#
# NameError: name 'CONFIG_FILE_PATH' is not defined

# %%
import os
import urllib.request as request
import zipfile
from textsummerizer.logging import logger
from textsummerizer.utils.common import get_size
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import urllib.request as request
#       3 import zipfile
# ----> 4 from textsummerizer.textsummerizer.logging import logger
#       5 from textsummerizer.utils.common import get_size
#
# ModuleNotFoundError: No module named 'textsummerizer'
